# %%
# %load_ext autoreload

import numpy as np
import pandas as pd
# from databrewery import source_configs

import databrewery as db
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
cb = db.CraftBrewery()
# Out:
# Loading the following DataKegs
# ...
# aviso          1993-01-01 : 2018-12-31   FTP     ssh, adt, sla, current_u, current_v
# ccmp           1987-06-01 : 2018-12-31   HTTP    wind_u, wind_v, wind_speed
# ecco4          1992-01-01 : 2017-12-31   HTTPS   mixed_layer,
# en4            1981-01-01 : 2017-12-31   HTTPS   salinity, temperature
# era5           1981-01-01 : 2018-12-31   CDS     wind_u, wind_v, wind_speed, sea_level_pressure
# globcolour     2019-08-01 : 2019-11-20   FTP     chlorophyll,
# globcurrent    1993-01-01 : 2018-12-31   FTP     current_u, current_v
# oisst          1982-01-01 : 2018-12-31   HTTPS   temperature, seaice
# oc_cci         1997-09-01 : 2018-12-31   FTP     ocean_color, chlorophyll
# sst_cci        1982-01-01 : 2016-12-31   FTP     temperature, seaice
# smos_cec       2010-08-01 : 2017-12-31   FTP     salinity,
# smos_bec       2011-01-01 : 2016-12-31   SFTP    salinity,
# socat          2019-01-01 : 2019-11-21   HTTPS   fco2,
# ...

# %%
cb.aviso.download_data(slice('2010', '2011'), njobs=4, verbose=2)
# Out:
# ...
# File exists locally: /nfs/kryo/work/.../AVISO_dt_GLOB_allsat_L4_daily/2010/dt_global_allsat_phy_l4_20100101.nc
# File exists locally: /nfs/kryo/work/.../AVISO_dt_GLOB_allsat_L4_daily/2010/dt_global_allsat_phy_l4_20100402.nc
# File exists locally: /nfs/kryo/work/.../AVISO_dt_GLOB_allsat_L4_daily/2010/dt_global_allsat_phy_l4_20100102.nc
# File exists locally: /nfs/kryo/work/.../AVISO_dt_GLOB_allsat_L4_daily/2010/dt_global_allsat_phy_l4_20100403.nc
# File exists locally: /nfs/kryo/work/.../AVISO_dt_GLOB_allsat_L4_daily/2010/dt_global_allsat_phy_l4_20100702.nc
# File exists locally: /nfs/kryo/work/.../AVISO_dt_GLOB_allsat_L4_daily/2010/dt_global_allsat_phy_l4_20100103.nc
# File exists locally: /nfs/kryo/work/.../AVISO_dt_GLOB_allsat_L4_daily/2010/dt_global_allsat_phy_l4_20100703.nc
# File exists locally: /nfs/kryo/work/.../AVISO_dt_GLOB_allsat_L4_daily/2010/dt_global_allsat_phy_l4_20100404.nc
# ...

# %%
def apply_processor(self, processor):
